# %% [markdown]
# # 1. Web Scraping (static pages) with BeautifulSoap

# %% [markdown]
# Import the required libraries
#
# BeautifulSoup documentation: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Pandas documentation: https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html

# %% [markdown]
# **First click on the folder icon to connect Google Drive, the third one in the side menu. We need the connection to save the data in the end**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.setec.mk/"

# %% [markdown]
# Send a HTTP GET request to the URL

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<!--[if IE 7]> <html lang="mk" class="ie7 responsive" > <![endif]-->  \n<!--[if IE 8]> <html lang="mk" class="ie8 responsive" > <![endif]-->  \n<!--[if IE 9]> <html lang="mk" class="ie9 responsive" > <![endif]-->  \n<!--[if !IE]><!--> <html lang="mk" class="responsive" > <!--<![endif]-->  \n<head>\n\n\t<title>Сетек | сè од техника</title>\n\t\t<meta property="og:image:width" content="1200" />\n\t<meta property="og:image:height" content="630" />\n\t<meta property="og:image:type" content="image/jpeg" />\n\t<meta content="Сетек | сè од техника, Сетек се од техника" property="og:title" />\n<!--<meta content="ASUS VivoBook 15 S" property="og:title" /> -->\n\t<meta content="product" property="og:type" />\n<!--<meta content="" property="og:url" /> -->\n<!--<meta content="https://www.setec.mk/image/catalog/Product/_0.jpg" property="og:image" />  -->\n    <meta content="https://www.setec.mk/image/catalog/Promo/setec_logo_modal.jpg" property="og:image" /> \n\t<meta name="description" content="Сетек | Сè од техника" property="og:description" />\n\t<meta name="keywords" content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in" /> \n<!--\t<script src="https://ua.realtimely.io/script.js" data-site="SETEC" defer></script> -->\n\t<base href="https://setec.mk/" />\n\t<link href="//netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css" rel="stylesheet">\n\t<!-- Meta -->\n\t<meta charset="utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t\t<meta name="description" content="Сетек | сè од техника, Сетек се од техника" />\n\t\t\t<meta name="keywords" content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in" />\n\t\t\n\t\t<link href="https://setec.mk/index.php?route=common/home" rel="canonical" />\n\t\t<link href="https://setec.mk/image/catalog/favicon.png" rel="icon" />\n\t\t\n\t<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-PZHBZZX\');</script>\n<!-- End Google Tag Manager -->\n\n\t<!-- Google Fonts -->\n\t<link href="//fonts.googleapis.com/css?family=Poppins:300,400,500,600,700" rel="stylesheet" type="text/css">\n\t<link href="//fonts.googleapis.com/css?family=Roboto:800,700,600,500,400,300,200,100" rel="stylesheet" type="text/css">\n\t\n\t<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/bootstrap.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/animate.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/stylesheet.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/custom.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/responsive.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/menu.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/owl.carousel.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/font-awesome.min.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/jquery.vegas.css" />\n<link rel="stylesheet" type="text/css" href="catalog/view/theme/fastor/css/filter_product.css" />\n<link re ...

# %%
raw_html = response.text

# %% [markdown]
# Parse the raw html file with a html parser from BeautifulSoup

# %%
soup = BeautifulSoup(raw_html, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="mk" class="ie7 responsive" > <![endif]-->
# <!--[if IE 8]> <html lang="mk" class="ie8 responsive" > <![endif]-->
# <!--[if IE 9]> <html lang="mk" class="ie9 responsive" > <![endif]-->
# <!--[if !IE]><!-->
# <html class="responsive" lang="mk">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Сетек | сè од техника
#   </title>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="Сетек | сè од техника, Сетек се од техника" property="og:title"/>
#   <!--<meta content="ASUS VivoBook 15 S" property="og:title" /> -->
#   <meta content="product" property="og:type"/>
#   <!--<meta content="" property="og:url" /> -->
#   <!--<meta content="https://www.setec.mk/image/catalog/Product/_0.jpg" property="og:image" />  -->
#   <meta content="https://www.setec.mk/image/catalog/Promo/setec_logo_modal.jpg" property="og:image"/>
#   <meta content="Сетек | Сè од техника" name="description" property="og:description"/>
#   <meta content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in" name="keywords"/>
#   <!--	<script src="https://ua.realtimely.io/script.js" data-site="SETEC" defer></script> -->
#   <base href="https://setec.mk/"/>
#   <link href="//netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css" rel="stylesheet"/>
#   <!-- Meta -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="Сетек | сè од техника, Сетек се од техника" name="description">
#     <meta content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in" name="keywords"/>
#     <link href="https://setec.mk/index.php?route=common/home" rel="canonical">
#      <link href="https://setec.mk/image/catalog/favicon.png" rel="icon"/>
#      <!-- Google Tag Manager -->
#      <script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PZHBZZX');
#      </script>
#      <!-- End Google Tag Manager -->
#      <!-- Google Fonts -->
#      <link href="//fonts.googleapis.com/css?family=Poppins:300,400,500,600,700" rel="stylesheet" type="text/css"/>
#      <link href="//fonts.googleapis.com/css?family=Roboto:800,700,600,500,400,300,200,100" rel="stylesheet" type="text/css"/>
#      <link href="catalog/view/theme/fastor/css/bootstrap.css" rel="stylesheet" type="text/css">
#       <link href="catalog/view/theme/fastor/css/animate.css" rel="stylesheet" type="text/css">
#        <link href="catalog/view/theme/fastor/css/stylesheet.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/custom.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/responsive.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/menu.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/owl.carousel.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/jquery.vegas.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/filter_product.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/wide-grid.css" rel="stylesheet" type="text/css"/>
#        <link href="catalog/view/theme/fastor/css/spacing_20.css" rel="stylesheet" type="text/css"/>
#        <style type="text/css">
#         body,
# 		.product-filter .list-options select,
# 		.blog-article .post .box .box-heading {
# 			color: #000000;
# 		}
#
# 				a {
# 			color: #000000;
# 		}
#
# 				a:hover,
# 		div.pagination-results ul li.active {
# 			color: #ff6600;
# 		}
#
#
# 		     .product-info .radio-type-button span:hover,
# 		     .product-info .radio-type-button span.active,
# 		     .product-info .radio-type-button2 span:hover,
# 		     .product-info .radio-type-button2 span.active,
# 		     #main .mfilter-image ul li.mfilter-image-checked {
# 		          border-color: #ff6600;
# 		     }
#
# 		     .product-info .radio-type-button2 span.active {
# 		          background: #ff6600;
# 		     }
#
# 				.compare-info .price-new,
# 		.product-grid .product .price,
# 		.product-list .actions > div .price,
# 		.product-info .price .price-new,
# 		ul.megamenu li .product .price,
# 		.mini-cart-total td:last-child,
# 		.cart-total table tr td:last-child,
# 		.mini-cart-info td.total,
# 		.advanced-grid-products .product .right .price,
# 		.product-list .name-actions > .price,
# 		.today-deals-products .product .price,
# 		.medic-last-in-stock .price,
# 		.architecture-products .product .right .price,
# 		.matrialarts-products .matrial-product .right .price,
# 		.today-deals-toys2-products .price,
# 		.today-deals-petshop2-products .price,
# 		.today-deals-shoes3-products .price,
# 		.today-deals-computer8-products .price,
# 		.today-deals-computer6-products .price,
# 		.holidays-products .product .right .price,
# 		.today-deals-computer6-products .countdown-section {
# 			color: #ff6600;
# 		}
#
# 				.product-list .name-actions > .price .price-old,
# 		.product-grid .product .price .price-old,
# 		.today-deals-products .product .price .price-old,
# 		.architecture-products .product .right .price .price-old,
# 		.today-deals-toys2-products .price .price-old,
# 		.today-deals-petshop2-products .price .price-old,
# 		.today-deals-shoes3-products .price .price-old,
# 		.today-deals-computer8-products .price .price-old,
# 		.today-deals-computer6-products .price .price-old {
# 			color: #3a3a3a;
# 		}
#
#
# 				body,
# 		.standard-body .full-width #mfilter-content-container > span:before {
# 			background: #f8f8f8;
# 		}
#
# 				.product-grid .product:hover:before,
# 		.product-list > div:hover {
# 			border-color: #ff6600;
# 		}
#
# 				.product-grid .product .only-hover ul li a,
# 		.architecture-products .product .right .only-hover ul li a,
# 		.product-list .name-actions ul li a,
# 		.today-deals-toys2-products .only-hover ul li a,
# 		.today-deals-petshop2-products .only-hover ul li a,
# 		.flower-product .right ul li a {
# 			background-color: #fff;
# 		}
#
# 				.product-grid .product .only-hover ul li a,
# 		.architecture-products .product .right .only-hover ul li a,
# 		.product-list .name-actions ul li a,
# 		.today-deals-toys2-products .only-hover ul li a,
# 		.today-deals-petshop2-products .only-hover ul li a,
# 		.flower-product .right ul li a {
# 			border-color: #ccc;
# 		}
#
# 				.product-grid .product .only-hover ul li a,
# 		.architecture-products .product .right .only-hover ul li a,
# 		.product-list .name-actions ul li a,
# 		.today-deals-toys2-products .only-hover ul li a,
# 		.today-deals-petshop2-products .only-hover ul li a,
# 		.flower-product .right ul li a {
# 			color: #000000;
# 		}
#
# 				.product-grid .product .only-hover ul li a:hover,
# 		.architecture-products .product .right .only-hover ul li a:hover,
# 		.product-list .name-actions ul li a:hover,
# 		.today-deals-toys2-products .only-hover ul li a:hover,
# 		.today-deals-petshop2-products .only-hover ul li a:hover,
# 		.flower-product .right ul li a:hover {
# 			background-color: #ff6600;
# 		}
#
# 				.product-grid .product .only-hover ul li a:hover,
# 		.architecture-products .product .right .only-hover ul li a:hover,
# 		.product-list .name-actions ul li a:hover,
# 		.today-deals-toys2-products .only-hover ul li a:hover,
# 		.today-deals-petshop2-products .only-hover ul li a:hover,
# 		.flower-product .right ul li a:hover {
# 			border-color: #ff6600;
# 		}
#
# 				.product-grid .product .only-hover ul li a:hover,
# 		.architecture-products .product .right .only-hover ul li a:hover,
# 		.product-list .name-actions ul li a:hover,
# 		.today-deals-toys2-products .only-hover ul li a:hover,
# 		.today-deals-petshop2-products .only-hover ul li a:hover,
# 		.flower-product .right ul li a:hover {
# 			color: #fff;
# 		}
#
#
#
#
# 				.dropdown-menu li a:hover,
# 		.dropdown-menu .mini-cart-info a:hover,
# 		.ui-autocomplete li a:hover,
# 		.ui-autocomplete li a.ui-state-focus {
# 			color: #ff6600 !important;
# 		}
#
# 				textarea,
# 		input[type="text"],
# 		input[type="password"],
# 		input[type="datetime"],
# 		input[type="datetime-local"],
# 		input[type="date"],
# 		input[type="month"],
# 		input[type="time"],
# 		input[type="week"],
# 		input[type="number"],
# 		input[type="email"],
# 		input[type="url"],
# 		input[type="search"],
# 		input[type="tel"],
# 		input[type="color"],
# 		.uneditable-input {
# 			background: #fff;
# 		}
#
# 				textarea:focus,
# 		input[type="text"]:focus,
# 		input[type="password"]:focus,
# 		input[type="datetime"]:focus,
# 		input[type="datetime-local"]:focus,
# 		input[type="date"]:focus,
# 		input[type="month"]:focus,
# 		input[type="time"]:focus,
# 		input[type="week"]:focus,
# 		input[type="number"]:focus,
# 		input[type="email"]:focus,
# 		input[type="url"]:focus,
# 		input[type="search"]:focus,
# 		input[type="tel"]:focus,
# 		input[type="color"]:focus,
# 		.uneditable-input:focus {
# 			background: #fff;
# 		}
#
# 				textarea,
# 		input[type="text"],
# 		input[type="password"],
# 		input[type="datetime"],
# 		input[type="datetime-local"],
# 		input[type="date"],
# 		input[type="month"],
# 		input[type="time"],
# 		input[type="week"],
# 		input[type="number"],
# 		input[type="email"],
# 		input[type="url"],
# 		input[type="search"],
# 		input[type="tel"],
# 		input[type="color"],
# 		.uneditable-input {
# 			border: 1px solid #ccc;
# 		}
#
# 				textarea:focus,
# 		input[type="text"]:focus,
# 		input[type="password"]:focus,
# 		input[type="datetime"]:focus,
# 		input[type="datetime-local"]:focus,
# 		input[type="date"]:focus,
# 		input[type="month"]:focus,
# 		input[type="time"]:focus,
# 		input[type="week"]:focus,
# 		input[type="number"]:focus,
# 		input[type="email"]:focus,
# 		input[type="url"]:focus,
# 		input[type="search"]:focus,
# 		input[type="tel"]:focus,
# 		input[type="color"]:focus,
# 		.uneditable-input:focus {
# 			border: 1px solid #ff6600;
# 		}
#
# 				textarea,
# 		input[type="text"],
# 		input[type="password"],
# 		input[type="datetime"],
# 		input[type="datetime-local"],
# 		input[type="date"],
# 		input[type="month"],
# 		input[type="time"],
# 		input[type="week"],
# 		input[type="number"],
# 		input[type="email"],
# 		input[type="url"],
# 		input[type="search"],
# 		input[type="tel"],
# 		input[type="color"],
# 		.uneditable-input {
# 			color: #3a3a3a;
# 		}
#
# 		.mfilter-price-inputs input {
# 		     color: #3a3a3a !important;
# 		}
#
# 				select {
# 			background: #ffffff;
# 		}
#
# 				select {
# 			border-color: #6e6e6e;
# 		}
#
# 				select {
# 			color: #3a3a3a;
# 		}
#
# 				.select:after,
# 		.product-filter .list-options .sort:after,
# 		.product-filter .list-options .limit:after {
# 			color: #ff6600;
# 		}
#
#
#
#
#
#
#
#
#
#
#
# 				.box .box-heading,
# 		.product-block .title-block,
# 		.refine_search {
# 			color: #000;
# 		}
#
# 				.box .box-heading,
# 		.product-block .title-block,
# 		.refine_search,
# 		.market-products-categories > ul > li > a {
# 			border-bottom-color: #ff6600;
# 		}
#
#
#
# 				.col-sm-3 .box-no-advanced.box .box-content, .col-sm-4 .box-no-advanced.box .box-content, .col-md-3 .box-no-advanced.box .box-content, .col-md-4 .box-no-advanced.box .box-content {
# 			border: 1px solid #e5e5e5;
# 		}
#
# 		          		.col-sm-3 .box-no-advanced.box .box-heading, .col-sm-4 .box-no-advanced.box .box-heading, .col-md-3 .box-no-advanced.box .box-heading, .col-md-4 .box-no-advanced.box .box-heading {
#      		     border: none;
#      		}
#
#
#
#
#
#
#
#
#
#
# 				.header-type-3 #top .search_form,
# 		.header-type-8 #top .search_form,
# 		.body-header-type-27 #top .search_form {
# 			border-color: #000000;
# 		}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				.top-bar {
# 			background: #182e4a;
# 		}
#
#
#
#
#
# 				#top > .background {
# 			background: #182e4a;
# 		}
#
#
# 				.megamenu-background {
# 			border-bottom-color: none;
# 		}
#
# 		     		     .megamenu-background {
# 		          border-bottom: none;
# 		     }
#
#
#
# 				.top-bar .menu li a,
# 		.header-type-9 #top #header-center .menu li a,
# 		.header-type-17 #top #header-left .menu li a,
# 		.header-type-26 #top .menu li a {
# 			color: #fff;
# 		}
#
# 				.top-bar .menu li a:hover,
# 		.header-type-9 #top #header-center .menu li a:hover,
# 		.header-type-17 #top #header-left .menu li a:hover,
# 		.header-type-26 #top .menu li a:hover {
# 			color: #ff6600;
# 		}
#
# 				#top .search_form input {
# 			background: #fff;
# 		}
#
# 				#top .search_form input:focus {
# 			background: #fff;
# 		}
#
# 				#top .search_form input {
# 			border: 1px solid #fff;
# 		}
#
# 				#top .search_form input:focus {
# 			border: 1px solid #fff;
# 		}
#
# 				#top .search_form input {
# 			color: #3a3a3a;
# 		}
#
# 		#top .search_form input::-webkit-input-placeholder { /* WebKit, Blink, Edge */
# 		    color:    #3a3a3a;
# 		}
#
# 		#top .search_form input:-moz-placeholder { /* Mozilla Firefox 4 to 18 */
# 		   color:    #3a3a3a;
# 		   opacity:  1;
# 		}
#
# 		#top .search_form input::-moz-placeholder { /* Mozilla Firefox 19+ */
# 		   color:    #3a3a3a;
# 		   opacity:  1;
# 		}
#
# 		#top .search_form input:-ms-input-placeholder { /* Internet Explorer 10-11 */
# 		   color:    #3a3a3a;
# 		}
#
# 				.search_form .button-search,
# 		.search_form .button-search2 {
# 			color: #000;
# 		}
#
# 				#top .dropdown > a:after {
# 			color: #fff;
# 		}
#
# 				#top .dropdown > a {
# 			color: #fff;
# 		}
#
# 				#top .dropdown:hover > a {
# 			color: #ff6600;
# 		}
#
# 				#top .dropdown:hover > a:after {
# 			color: #ff6600;
# 		}
#
# 				#top .my-account,
# 		.rtl .header-type-10 #top .my-account {
# 			border-color: #ffffff;
# 					}
#
# 				#top .my-account {
# 			background: none;
# 		}
#
#
# 				#top .my-account,
# 		.header-type-23 .dropdown i {
# 			color: #000;
# 		}
#
# 				#top .my-account:hover,
# 		.rtl .header-type-10 #top .my-account:hover {
# 			border-color: #fff;
# 		}
#
# 				#top .my-account:hover {
# 			background: #fff;
# 		}
#
#
# 				#top .my-account:hover,
# 		.header-type-23 .dropdown:hover i {
# 			color: #000;
# 		}
#
# 				#top #cart_block .cart-heading .cart-icon,
# 		.cart-block-type-2 #top #cart_block .cart-heading,
# 		.cart-block-type-9 #top #cart_block .cart-heading,
# 		.cart-block-type-8 #top #cart_block .cart-heading,
# 		.cart-block-type-7 #top #cart_block .cart-heading,
# 		.cart-block-type-4 #top #cart_block .cart-heading,
# 		.cart-block-type-6 #top #cart_block .cart-heading,
# 		.cart-block-type-8 #top #cart_block .cart-heading p,
# 		.cart-block-type-4 #top #cart_block .cart-heading .cart-icon,
# 		.rtl .cart-block-type-8 #top #cart_block .cart-heading p,
# 		.rtl .header-type-10 #top #cart_block .cart-heading .cart-icon,
# 		.rtl .cart-block-type-4 #top #cart_block .cart-heading .cart-icon {
# 			border-color: #ffffff;
# 		}
#
#
#
# 				#top #cart_block .cart-heading .cart-icon,
# 		.cart-block-type-2 #top #cart_block .cart-heading,
# 		.cart-block-type-9 #top #cart_block .cart-heading,
# 		.cart-block-type-8 #top #cart_block .cart-heading,
# 		.cart-block-type-7 #top #cart_block .cart-heading,
# 		.cart-block-type-4 #top #cart_block .cart-heading {
# 			background: none;
# 		}
#
#
# 				#top #cart_block:hover .cart-heading .cart-icon,
# 		.cart-block-type-2 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-9 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-8 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-7 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-4 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-6 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-8 #top #cart_block:hover .cart-heading p,
# 		.cart-block-type-4 #top #cart_block:hover .cart-heading .cart-icon,
# 		.rtl .cart-block-type-8 #top #cart_block:hover .cart-heading p,
# 		.rtl .header-type-10 #top #cart_block:hover .cart-heading .cart-icon,
# 		.rtl .cart-block-type-4 #top #cart_block:hover .cart-heading .cart-icon {
# 			border-color: #fff;
# 		}
#
#
# 				#top #cart_block:hover .cart-heading .cart-icon,
# 		.cart-block-type-2 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-9 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-8 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-7 #top #cart_block:hover .cart-heading,
# 		.cart-block-type-4 #top #cart_block:hover .cart-heading {
# 			background: #fff;
# 		}
#
#
# 				#top #cart_block .cart-heading .cart-count {
# 			color: #000;
# 		}
#
# 				#top #cart_block .cart-heading .cart-count {
# 			background-color: #fff;
# 		}
#
#
# 				#top #cart_block .cart-heading p {
# 			color: #fff;
# 		}
#
# 				#top #cart_block .cart-heading p:after {
# 			color: #ffffff;
# 		}
#
# 				#top #cart_block:hover .cart-heading .cart-count {
# 			color: #000000;
# 		}
#
# 				#top #cart_block:hover .cart-heading .cart-count {
# 			background-color: #fff;
# 		}
#
#
# 				#top #cart_block:hover .cart-heading p {
# 			color: #ffffff;
# 		}
#
# 				#top #cart_block:hover .cart-heading p:after {
# 			color: #fff;
# 		}
#
# 				#main .mfilter-slider-slider .ui-slider-handle, #main #mfilter-price-slider .ui-slider-handle {
# 		     background: #ff6600 !important;
# 		}
#
# 				#main .mfilter-slider-slider .ui-slider-range, #main #mfilter-price-slider .ui-slider-range {
# 		     background: #ff6600 !important;
# 		}
#
# 				ul.megamenu > li.with-sub-menu > a strong:after {
# 			color: #fff;
# 		}
#
# 				ul.megamenu > li.with-sub-menu:hover > a strong:after {
# 			color: #ff6600;
# 		}
#
#
#
# 				ul.megamenu > li > a {
# 			color: #fff;
# 		}
#
# 				ul.megamenu > li:hover > a,
# 		ul.megamenu > li.active > a,
# 		ul.megamenu > li.home > a {
# 			color: #ff6600;
# 		}
#
#
#
#
# 				#main .vertical .megamenuToogle-wrapper .container {
# 			color: #fff;
# 		}
#
# 				#main .vertical .megamenuToogle-wrapper .container:after {
# 			color: #fff;
# 		}
#
# 		.megamenu-type-15 .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-15 .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-15 .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 		.megamenu-type-20 .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-20 .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-20 .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 		.megamenu-type-34 .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-34 .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-34 .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 		.megamenu-type-28 .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-28 .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-28 .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 		.megamenu-type-25 .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-25 .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-25 .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 		.megamenu-type-18 .slideshow-modules .vertical .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-18 .slideshow-modules .vertical .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-18 .slideshow-modules .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 				#main .vertical .megamenuToogle-wrapper,
# 		.standard-body .full-width .megamenu-background .mega-menu-modules > div:first-child:before {
# 			background-color: #ff6600;
# 		}
#
# 		     @media (max-width: 991px) {
#      		     .responsive .standard-body .full-width .megamenu-background .megaMenuToggle:before {
#      		          background-color: #ff6600;
#      		     }
# 		     }
#
#
# 				#main .vertical:hover .megamenuToogle-wrapper .container,
# 		.common-home.show-vertical-megamenu #main .megamenu-background .vertical .megamenuToogle-wrapper .container,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page #main .megamenu-background .vertical .megamenuToogle-wrapper .container,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page #main .megamenu-background .vertical .megamenuToogle-wrapper .container,
# 		.common-home.show-vertical-megamenu #main .slideshow-modules .vertical .megamenuToogle-wrapper .container {
# 			color: #fff;
# 		}
#
# 				#main .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after {
# 			color: #fff;
# 		}
#
# 		.megamenu-type-15 .megamenu-background .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-15 .megamenu-background .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-15 .megamenu-background .vertical:hover .megamenuToogle-wrapper:before,
# 		.megamenu-type-18 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-18 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-18 .slideshow-modules .vertical:hover .megamenuToogle-wrapper:before,
# 		.megamenu-type-20 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-20 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-20 .slideshow-modules .vertical:hover .megamenuToogle-wrapper:before,
# 		.megamenu-type-34 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-34 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-34 .slideshow-modules .vertical:hover .megamenuToogle-wrapper:before,
# 		.megamenu-type-28 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-28 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-28 .slideshow-modules .vertical:hover .megamenuToogle-wrapper:before,
# 		.megamenu-type-25 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:before,
# 		.megamenu-type-25 .slideshow-modules .vertical:hover .megamenuToogle-wrapper .container:after,
# 		.megamenu-type-25 .slideshow-modules .vertical:hover .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		.common-home.show-vertical-megamenu.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		.common-home.show-vertical-megamenu.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-15 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-18 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-20 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-34 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-28 #main .megamenu-background .vertical .megamenuToogle-wrapper:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:before,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper .container:after,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page.megamenu-type-25 #main .megamenu-background .vertical .megamenuToogle-wrapper:before {
# 		     background: #fff;
# 		}
#
# 				#main .vertical:hover .megamenuToogle-wrapper,
# 		.common-home.show-vertical-megamenu #main .megamenu-background .vertical .megamenuToogle-wrapper,
# 		body[class*="product-category-"].show-vertical-megamenu-category-page #main .megamenu-background .vertical .megamenuToogle-wrapper,
# 		body[class*="product-product-"].show-vertical-megamenu-product-page #main .megamenu-background .vertical .megamenuToogle-wrapper,
# 		.common-home.show-vertical-megamenu #main .slideshow-modules .vertical .megamenuToogle-wrapper {
# 			background-color: #ff6600 !important;
# 		}
#
#
# 				#main .vertical .megamenu-wrapper {
# 			background-color: #ffffff !important;
# 		}
#
#
#
#
# 				#main .vertical ul.megamenu > li > a {
# 			color: #000000;
# 		}
#
# 				#main .vertical ul.megamenu > li:hover > a,
# 		#main .vertical ul.megamenu > li.active > a {
# 			color: #ffffff;
# 		}
#
# 				#main .vertical ul.megamenu > li:hover {
# 			background: #ff6600;
# 		}
#
# 				#main .vertical ul.megamenu > li.with-sub-menu > a:before,
# 		#main .vertical ul.megamenu > li.with-sub-menu > a:after {
# 			color: #000000;
# 		}
#
# 				#main .vertical ul.megamenu > li.with-sub-menu:hover > a:before,
# 		#main .vertical ul.megamenu > li.with-sub-menu:hover > a:after {
# 			color: #ffffff;
# 		}
#
#
#
#
# 				ul.megamenu li .sub-menu .content a:hover,
# 		ul.megamenu li .sub-menu .content .hover-menu .menu ul li:hover > a {
# 			color: #a27050;
# 		}
#
# 				ul.megamenu li .sub-menu .content .hover-menu a.with-submenu:before {
# 			color: #a27050;
# 		}
#
#
# 				ul.megamenu li .sub-menu .content .static-menu a.main-menu{
# 			color: #000;
# 		}
#
# 				ul.megamenu li .sub-menu .content .static-menu a.main-menu:hover {
# 			color: #ff6600;
# 		}
#
# 				ul.megamenu li .sub-menu .content .static-menu a.main-menu:after {
# 			background: #ff6600;
# 		}
#
#
# 				.megamenuToogle-wrapper {
# 			background: #182e4a; /* Old browsers */
# 			background: -moz-linear-gradient(top, #182e4a 0%, #182e4a 0%, #182e4a 99%); /* FF3.6+ */
# 			background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,#182e4a), color-stop(0%,#182e4a), color-stop(99%,#182e4a)); /* Chrome,Safari4+ */
# 			background: -webkit-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* Chrome10+,Safari5.1+ */
# 			background: -o-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* Opera 11.10+ */
# 			background: -ms-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* IE10+ */
# 			background: linear-gradient(to bottom, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* W3C */
# 		}
#
#
# 				.megamenuToogle-wrapper .container {
# 			color: #fff;
# 		}
#
# 				.megamenuToogle-wrapper .container > div span {
# 			background: #fff;
# 		}
#
#
# 				.megamenuToogle-wrapper:hover,
# 		.active .megamenuToogle-wrapper {
# 			background: #182e4a; /* Old browsers */
# 			background: -moz-linear-gradient(top, #182e4a 0%, #182e4a 0%, #182e4a 99%); /* FF3.6+ */
# 			background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,#182e4a), color-stop(0%,#182e4a), color-stop(99%,#182e4a)); /* Chrome,Safari4+ */
# 			background: -webkit-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* Chrome10+,Safari5.1+ */
# 			background: -o-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* Opera 11.10+ */
# 			background: -ms-linear-gradient(top, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* IE10+ */
# 			background: linear-gradient(to bottom, #182e4a 0%,#182e4a 0%,#182e4a 99%); /* W3C */
# 		}
#
#
# 				.megamenuToogle-wrapper:hover .container,
# 		.active .megamenuToogle-wrapper .container {
# 			color: #fff;
# 		}
#
# 				.megamenuToogle-wrapper:hover .container > div span,
# 		.active .megamenuToogle-wrapper .container > div span {
# 			background: #fff;
# 		}
#
# 				@media (max-width: 991px) {
#      		.responsive .horizontal .megamenu-wrapper {
#      			background: #fff !important;
#      		}
# 		}
#
#
# 				@media (max-width: 991px) {
# 			.responsive .horizontal ul.megamenu > li > a {
# 				color: #000 !important;
# 			}
# 		}
#
# 				@media (max-width: 991px) {
# 			.responsive .horizontal ul.megamenu > li:hover > a,
# 			.responsive .horizontal ul.megamenu > li.active > a {
# 				color: #a27050 !important;
# 			}
# 		}
#
# 				@media (max-width: 991px) {
# 			.responsive .horizontal ul.megamenu > li {
# 				border-top-color: #e5e5e5 !important;
# 			}
# 		}
#
# 				@media (max-width: 991px) {
# 			.responsive ul.megamenu > li:hover,
# 			.responsive ul.megamenu > li.active {
# 				background: #fff !important;
# 			}
# 		}
#
# 				@media (max-width: 991px) {
# 			.responsive ul.megamenu > li.with-sub-menu .open-menu,
# 			.responsive ul.megamenu > li.with-sub-menu .close-menu {
# 				color: #000 !important;
# 			}
# 		}
#
#
#
#
#
#
# 				#main .breadcrumb .background {
# 			background: none;
# 		}
#
#
#
# 				#main .breadcrumb .background {
# 			border-top: 1px solid #e5e5e5;
# 			background-image: none;
# 		}
#
# 				.breadcrumb .container h1 {
# 			color: #000;
# 		}
#
# 				.breadcrumb .container h1 {
# 			border-bottom-color: #ff6600;
# 		}
#
# 				.breadcrumb ul,
# 		.breadcrumb ul a {
# 			color: #000000;
# 		}
#
# 				.breadcrumb ul a:hover {
# 			color: #ff6600;
# 		}
#
# 				.next-product .right .price {
# 			color: #ff6600;
# 		}
#
#
#
# 				.button-previous-next {
# 			color: #ff6600;
# 		}
#
# 				.button-previous-next:hover {
# 			background: #ff6600;
# 		}
#
# 				.button-previous-next:hover {
# 			border-color: #ff6600;
# 		}
#
# 				.button-previous-next:hover {
# 			color: #fff;
# 		}
#
# 				#main .box-with-categories .box-content {
# 			background: #262626 !important;
# 		}
#
#
#
# 				.box-category > ul li {
# 			border-top-color: #363636;
# 		}
#
# 				#main .box-category ul li > a {
# 			color: #fff;
# 		}
#
# 				#main .box-category ul li > a:hover {
# 			color: #ff6600;
# 		}
#
# 				#main .box-category ul li a.active {
# 			color: #ff6600;
# 		}
#
# 				.box-category > ul li > a:hover,
# 		.box-category > ul li:hover > a,
# 		.box-category > ul li a.active {
# 			background: #292929;
# 		}
#
# 				#main .box-category ul li .head a {
# 			color: #fff;
# 		}
#
# 				.box-with-categories .box-heading {
# 			background: #262626;
# 		}
#
#
# 				.box-with-categories .box-heading {
# 			color: #fff;
# 		}
#
#
#
#
#
#
#
#
#
#
#
#
# 				.box > .prev:hover,
# 		.box > .next:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-prev:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-next:hover,
# 		div.pagination-results ul li:hover,
# 		.tab-content .prev-button:hover,
# 		.tab-content .next-button:hover {
# 			background: #ff6600;
# 		}
#
#
# 				.box > .prev:hover,
# 		.box > .next:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-prev:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-next:hover,
# 		div.pagination-results ul li:hover,
# 		.tab-content .prev-button:hover,
# 		.tab-content .next-button:hover {
# 			color: #fff;
# 		}
#
# 				.box > .prev:hover,
# 		.box > .next:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-prev:hover,
# 		.product-info .thumbnails-carousel .owl-buttons .owl-next:hover,
# 		div.pagination-results ul li:hover,
# 		.tab-content .prev-button:hover,
# 		.tab-content .next-button:hover {
# 			border-color: #ff6600;
# 		}
#
# 				.filter-product .filter-tabs ul > li.active > a, .filter-product .filter-tabs ul > li.active > a:hover, .filter-product .filter-tabs ul > li.active > a:focus, .htabs a.selected, .htabs a:hover {
# 			color: #000;
# 		}
#
# 				.htabs a.selected:before,
# 		.filter-product .filter-tabs ul > li.active > a:before {
# 			background: #ff6600;
# 		}
#
# 				.filter-product .filter-tabs ul > li > a,
# 		.htabs a {
# 			color: #808080;
# 		}
#
# 				.categories-wall .category-wall h3 {
# 			border-bottom-color: #ff6600;
# 		}
#
#
#
#
#
#
#
# 				.popup h4:after {
# 			background: #ff6600;
# 		}
#
#
#
#
#
#
#
#
#
# 				body .popup-module .mfp-close {
# 			border-color: #ff6600;
# 		}
#
# 				body .popup-module .mfp-close {
# 			color: #ff6600;
# 		}
#
# 				body .popup-module .mfp-close:hover {
# 			background: #ff6600;
# 		}
#
# 				body .popup-module .mfp-close:hover {
# 			border-color: #ff6600;
# 		}
#
# 				body .popup-module .mfp-close:hover {
# 			color: #fff;
# 		}
#
# 				#slider .pattern {
# 			background: #fff;
# 		}
#
# 		.spinner {
# 		     background-color: #fff;
# 		}
#
#
#
#
# 				.camera_wrap .owl-controls .owl-buttons .owl-prev:hover, .camera_wrap .owl-controls .owl-buttons .owl-next:hover,
# 		#main .tp-leftarrow.default:hover,
# 		#main .tp-rightarrow.default:hover,
# 		#main .post .post-media .media-slider .owl-controls .owl-buttons .owl-prev:hover,
# 		#main .post .post-media .media-slider .owl-controls .owl-buttons .owl-next:hover {
# 			background: #ff6600;
# 		}
#
#
# 				.camera_wrap .owl-controls .owl-buttons .owl-prev:hover:before, .camera_wrap .owl-controls .owl-buttons .owl-next:hover:before,
# 		#main .tp-leftarrow.default:hover:before,
# 		#main .tp-rightarrow.default:hover:before,
# 		#main .post .post-media .media-slider .owl-controls .owl-buttons .owl-prev:hover:before,
# 		#main .post .post-media .media-slider .owl-controls .owl-buttons .owl-next:hover:before {
# 			color: #fff;
# 		}
#
#
#
#
# 				.sale {
# 			background: #ff6600;
# 		}
#
#
# 				.sale {
# 			color: #fff;
# 		}
#
#
# 				#main .new {
# 			background: #ff6600;
# 		}
#
#
# 				#main .new {
# 			color: #fff;
# 		}
#
#
# 				.rating i.active {
# 			color: #ff6600;
# 		}
#
# 				.button, .btn {
# 			color: #fff !important;
# 		}
#
# 				.button, .btn {
# 			background: #ff6600 !important;
# 		}
#
#
#
# 				.button:hover, .btn:hover {
# 			color: #fff !important;
# 		}
#
#
# 				.button:hover, .btn:hover {
# 			background: #ff4400 !important;
# 		}
#
#
# 				.buttons .left .button, .buttons .center .button, .btn-default, .input-group-btn .btn-primary {
# 			color: #fff !important;
# 		}
#
#
# 				.buttons .left .button, .buttons .center .button, .btn-default, .input-group-btn .btn-primary {
# 			background: #ff6600 !important;
# 		}
#
#
# 				.buttons .left .button:hover, .buttons .center .button:hover, .btn-default:hover, .input-group-btn .btn-primary:hover {
# 			color: #fff !important;
# 		}
#
#
# 				.buttons .left .button:hover, .buttons .center .button:hover, .btn-default:hover, .input-group-btn .btn-primary:hover {
# 			background: #ff4400 !important;
# 		}
#
#
#
#
#
#
# 				.custom-footer h4,
# 		.custom-footer .background,
# 		.standard-body .custom-footer .background,
# 		.fb-like-box,
# 		ul.contact-us li i {
# 			border-color: none;
# 		}
#
# 				.custom-footer .background,
# 		.standard-body .custom-footer .background {
# 			background: none;
# 		}
#
# 		.custom-footer .pattern {
# 			background: none;
# 		}
#
# 				.footer .pattern,
# 		.footer .pattern a {
# 			color: #000000;
# 		}
#
# 				.footer .pattern a {
# 			color: #000000;
# 		}
#
# 				.footer .pattern a:hover {
# 			color: #ff6600;
# 		}
#
# 				.footer h4 {
# 			color: #000000;
# 		}
#
# 				.footer h4 {
# 			border-bottom-color: #ff6600;
# 		}
#
# 				.footer .background,
# 		.standard-body .footer .background,
# 		.copyright .background,
# 		.standard-body .copyright .background {
# 			background: none;
# 		}
#
# 				.footer .container > .row:before,
# 		.footer .advanced-grid .container > div > .row:before,
# 		.footer .container > .row > div:before,
# 		.footer .advanced-grid .container > div > .row > div:before,
# 		.footer-type-11 .footer .container > .row:nth-last-child(2) > div:before,
# 		.footer-type-11 .footer .advanced-grid .container > div > .row:nth-last-child(2) > div:before,
# 		.footer-type-16 .footer .container > .row:nth-last-child(2) > div:before,
# 		.footer-type-16 .footer .advanced-grid .container > div > .row:nth-last-child(2) > div:before,
# 		.footer-type-21 .footer .container > .row > div:last-child:after,
# 		.footer-type-21 .footer .advanced-grid .container > div > .row > div:last-child:after {
# 			background: #e5e5e5;
# 		}
#
# 		.footer-type-11 .footer .container > .row:nth-last-child(2),
# 		.footer-type-11 .footer .advanced-grid .container > div > .row:nth-last-child(2),
# 		.footer-type-16 .footer .container > .row:nth-last-child(2),
# 		.footer-type-16 .footer .advanced-grid .container > div > .row:nth-last-child(2) {
# 		     border-color: #e5e5e5;
# 		}
#
# 				.footer-button {
# 			color: #fff !important;
# 		}
#
# 				.footer-button {
# 			background: #ff6600;
# 		}
#
#
# 				.footer-button:hover {
# 			color: #fff !important;
# 		}
#
# 				.footer-button:hover {
# 			background: #ff4400;
# 		}
#
#
# 				#main .post .date-published,
# 		#main .news.v2 .media-body .bottom,
# 		.cosmetics-news .media .date-published,
# 		.medic-news .media .date-published,
# 		.wine-news .media .date-published,
# 		.cameras-news .media .date-published {
# 			color: #000;
# 		}
#
# 				#main .post .meta > li a {
# 			color: #ff6600;
# 		}
#
# 				#main .post .meta > li a:hover {
# 			color: #000;
# 		}
#
# 				#main .tagcloud a,
# 		#main .post .tags a,
# 		#main .news .media-body .tags a,
# 		#main .posts .post .tags a,
# 		.cosmetics-news .media .tags a,
# 		.cameras-news .media .tags a {
# 			color: #fff;
# 		}
#
# 				#main .tagcloud a,
# 		#main .post .tags a,
# 		#main .news .media-body .tags a,
# 		#main .posts .post .tags a,
# 		.cosmetics-news .media .tags a,
# 		.cameras-news .media .tags a {
# 			background: #ff6600;
# 		}
#
#
# 				#main .tagcloud a:hover,
# 		#main .post .tags a:hover,
# 		#main .news .media-body .tags a:hover,
# 		#main .posts .post .tags a:hover,
# 		.cosmetics-news .media .tags a:hover,
# 		.cameras-news .media .tags a:hover {
# 			color: #fff;
# 		}
#
# 				#main .tagcloud a:hover,
# 		#main .post .tags a:hover,
# 		#main .news .media-body .tags a:hover,
# 		#main .posts .post .tags a:hover,
# 		.cosmetics-news .media .tags a:hover,
# 		.cameras-news .media .tags a:hover {
# 			background: #000;
# 		}
#
#
#
#
# 				#main .posts .button-more,
# 		.wine-news .button-more {
# 			color: #ff6600;
# 		}
#
# 				#main .posts .button-more:hover,
# 		.wine-news .button-more:hover {
# 			background: #ff6600;
# 		}
#
# 				#main .posts .button-more:hover,
# 		.wine-news .button-more:hover {
# 			border-color: #ff6600;
# 		}
#
# 				#main .posts .button-more:hover,
# 		.wine-news .button-more:hover {
# 			color: #fff;
# 		}
#
# 			body,
# 		textarea, input[type="text"], input[type="password"], input[type="datetime"], input[type="datetime-local"], input[type="date"], input[type="month"], input[type="time"], input[type="week"], input[type="number"], input[type="email"], input[type="url"], input[type="search"], input[type="tel"], input[type="color"], .uneditable-input, select {
# 			font-size: 14px;
# 			font-weight: 400 !important;
# 						font-family: Roboto;
# 					}
#
# 		ul.megamenu .megamenu-label,
# 		#main .news .media-body h5,
# 		#main .posts .post .post-title {
# 		     		     font-family: Roboto;
# 		     		}
#
# 		@media (max-width: 767px) {
# 		     .responsive ul.megamenu li .sub-menu .content .hover-menu .menu ul li a,
# 		     .responsive ul.megamenu li .sub-menu .content .static-menu .menu ul li a {
# 		          		          font-family: Roboto;
# 		          		     }
# 		}
#
#
#
#
#
#
# 		.center-column .panel-heading h4 {
# 		     		     font-family: Roboto;
# 		     		}
#
# 		.dropdown-menu,
# 		body .dropdown-menu > li > a,
# 		.top-bar .menu li a,
# 		#top .dropdown > a,
# 		.product-info .cart .add-to-cart p,
# 		.header-notice,
# 		.header-type-9 #top #header-center .menu li a,
# 		.welcome-text,
# 		.header-type-16 #top #header-left .menu li {
# 			font-size: 12px;
# 		}
#
#
# 		.product-filter .options .product-compare a,
# 		.product-info .cart .links a,
# 		.button-previous-next,
# 		.footer-button,
# 		.button-white-with-red-text,
# 		table.attribute thead td,
# 		table.list thead td,
# 		.wishlist-product table thead td,
# 		.wishlist-info table thead td,
# 		.compare-info thead td,
# 		.checkout-product table thead td,
# 		.table thead td,
# 		.cart-info table thead td,
# 		.manufacturer-heading,
# 		.center-column .panel-heading h4,
# 		ul.box-filter > li > span,
# 		.popup .form-contact .contact-label label,
# 		.categories-wall .category-wall .more-categories,
# 		.mfilter-heading,
# 		.product-info .options2 > div > label {
# 			font-size: 11px !important;
#
# 					}
#
# 		ul.megamenu li .sub-menu .content .static-menu a.main-menu {
# 			font-size: 14px;
# 			font-weight: 700 !important;
# 						font-family: Roboto;
#
#
# 						line-height: 1.5;
# 					}
#
# 		ul.megamenu > li > a strong,
# ...
#                          <span class="redovna-cena">
#                           Редовна цена:
#                          </span>
#                          <span class="price-old-new">
#                           1,499 Ден.
#                          </span>
#                         </div>
#                         <div class="category-price-akciska">
#                          <span class="akciska-cena">
#                           КЛУБ ЦЕНА:
#                          </span>
#                          <p style="clear: both; text-align: center; margin: 2px !important;">
#                          </p>
#                          <span class="price-new-new">
#                           899 Ден.
#                          </span>
#                         </div>
#                         <!-- RATI -->
#                         <div id="category-rata">
#                          <span class="klub-rata">
#                           РАТИ:
#                          </span>
#                          <div class="tooltip_nov">
#                           / Ден.
#                           <span class="tooltiptext_nov">
#                            Производи со цена помала од 2000 ден. немаат можност да се купат на рати.
#                           </span>
#                          </div>
#                         </div>
#                         <!-- RATI -->
#                        </div>
#                       </div>
#                       <div class="only-hover">
#                        <ul>
#                         <li>
#                          <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('75437');">
#                           <i class="fa fa-shopping-cart">
#                           </i>
#                          </a>
#                         </li>
#                         <li>
#                          <a data-original-title="Додади за споредба" data-toggle="tooltip" onclick="compare.add('75437');">
#                           <i class="fa fa-exchange">
#                           </i>
#                          </a>
#                         </li>
#                         <li>
#                          <a data-original-title="Додади во омилени" data-toggle="tooltip" onclick="wishlist.add('75437');">
#                           <i class="fa fa-heart">
#                           </i>
#                          </a>
#                         </li>
#                        </ul>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <script type="text/javascript">
#            $('#tab15591222 a').click(function (e) {
#   e.preventDefault();
#   $(this).tab('show');
# })
#           </script>
#           <div class="advanced-grid advanced-grid-18618633 border-1px hidden-xs hidden-sm" style="margin-top: 30px;margin-left: 0px;margin-right: 0px;margin-bottom: 0px;">
#            <div style="background-color: #fafafa;background-image: url(image/catalog/Logoa/bg-newsletter.jpg);background-position: top right;background-repeat: no-repeat;background-attachment: scroll;">
#             <div class="container">
#              <div style="padding-top: 0px;padding-left: 0px;padding-bottom: 0px;padding-right: 0px;">
#               <div class="row">
#                <div class="col-sm-12">
#                 <div class="market-newsletter clearfix row" id="newsletter18618633">
#                  <img alt="Newsletter" src="image/catalog/fashion8/icon-newsletter.png"/>
#                  <div class="col-sm-2 hidden-xs">
#                  </div>
#                  <div class="col-sm-3">
#                   <div class="heading">
#                    <p>
#                     Претплатете се на билтенот
#                     <br/>
#                     и добијте попуст
#                    </p>
#                   </div>
#                  </div>
#                  <div class="inputs col-sm-4">
#                   <input class="email" placeholder="емаил адреса" type="text"/>
#                   <a class="button subscribe">
#                    <i class="fa fa-plus">
#                    </i>
#                   </a>
#                  </div>
#                 </div>
#                 <div class="newsletter_rodo">
#                  <form id="agree_rodo_form2">
#                   <input name="agree_rodo2" required="required" type="checkbox" value="1"/>
#                   Се согласувам со
#                   <a href="/index.php?route=information/information&amp;information_id=3" target="_blank">
#                    <b>
#                     Општите услови и правила
#                    </b>
#                   </a>
#                   и
#                   <a href="/index.php?route=information/information&amp;information_id=14" target="_blank">
#                    <b>
#                     Политика на приватност
#                    </b>
#                   </a>
#                   .
#                   <input class="submit hidden" type="submit" value="Submit"/>
#                  </form>
#                 </div>
#                 <script type="text/javascript">
#                  $(document).ready(function() {
# 	function Unsubscribe() {
# 		$.post('https://setec.mk/index.php?route=extension/module/newsletter/unsubscribe',
# 			{
# 				email: $('#newsletter18618633 .email').val()
# 			}, function (e) {
# 				$('#newsletter18618633 .email').val('');
# 				alert(e.message);
# 			}
# 		, 'json');
# 	}
#
# 	function Subscribe() {
# 				if($('input[name="agree_rodo2"]').is(':checked')) {
# 				$.post('https://setec.mk/index.php?route=extension/module/newsletter/subscribe',
# 			{
# 				email: $('#newsletter18618633 .email').val()
# 			}, function (e) {
# 				if(e.error === 1) {
# 					var r = confirm(e.message);
# 					if (r == true) {
# 					    $.post('https://setec.mk/index.php?route=extension/module/newsletter/unsubscribe', {
# 					    	email: $('#newsletter18618633 .email').val()
# 					    }, function (e) {
# 					    	$('#newsletter18618633 .email').val('');
# 					    	alert(e.message);
# 					    }, 'json');
# 					}
# 				} else {
# 					$('#newsletter18618633 .email').val('');
# 					alert(e.message);
# 				}
# 			}
# 		, 'json');
# 				} else {
# 			$('#agree_rodo_form2 .submit').click();
# 		}
# 			}
#
# 	$('#newsletter18618633 .subscribe').click(Subscribe);
# 	$('#newsletter18618633 .unsubscribe').click(Unsubscribe);
# 	$('#newsletter18618633 .email').keypress(function (e) {
# 	    if (e.which == 13) {
# 	        Subscribe();
# 	    }
# 	});
# });
#                 </script>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- FOOTER
# 		================================================== -->
#     <div class="footer full-width">
#      <div class="background-footer">
#      </div>
#      <div class="background">
#       <div class="shadow">
#       </div>
#       <div class="pattern">
#        <div class="container">
#         <div class="advanced-grid advanced-grid-8374380 col-lg-12 col-md-12 col-sm-12 col-xs-12" style="margin-top: 0px;margin-left: 0px;margin-right: 0px;margin-bottom: 0px;">
#          <div style="">
#           <div class="container">
#            <div style="padding-top: 0px;padding-left: 0px;padding-bottom: 0px;padding-right: 0px;">
#             <div class="row">
#              <div class="col-sm-3">
#               <h4>
#                Информации
#               </h4>
#               <div class="strip-line">
#               </div>
#               <div class="row" style="clear: both">
#                <div class="col-sm-12">
#                 <ul>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=4">
#                    За нас
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/contact">
#                    Контакт
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=17">
#                    Продажни салони
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=10">
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=14">
#                    Политика на приватност
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=3">
#                    Општи услови и правила
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/contact">
#                    Грижа за корисници
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=13">
#                    Потрошувачки кредит
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=133">
#                    Клуб услови и правила
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://setec.mk/index.php?route=information/information&amp;information_id=249">
#                    Сертификат ФЕР со потрошувачот
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <div class="col-sm-3">
#               <h4>
#                За корисници
#               </h4>
#               <div class="strip-line">
#               </div>
#               <div class="row" style="clear: both">
#                <div class="col-sm-12">
#                 <ul>
#                  <li>
#                   <a href="index.php?route=information/information&amp;information_id=15">
#                    Вработување
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://setec.mk/index.php?route=information/information&amp;information_id=30">
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://cc.st.mk/Account/SignIn.aspx">
#                    Cashback проверка
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://mojservis.mk/">
#                    Мој Сервис
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://setec.mk/index.php?route=information/information&amp;information_id=679">
#                    Информации за испорака
#                   </a>
#                  </li>
#                  <li>
#                   <a href="http://outlet.setec.mk">
#                    Оутлет Производи
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <div class="col-sm-3">
#               <h4>
#                Корисничка сметка
#               </h4>
#               <div class="strip-line">
#               </div>
#               <div class="row" style="clear: both">
#                <div class="col-sm-12">
#                 <ul>
#                  <li>
#                   <a href="index.php?route=account/login">
#                    Податоци за корисникот
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/order">
#                    Историја на нарачки
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/wishlist">
#                    Листа на желби
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/newsletter">
#                    Билтен
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <div class="col-sm-3">
#               <div class="row banners banners-with-padding-45">
#                <a href="https://setec.mk/samsung">
#                 <img alt="Banner" src="image/catalog/Promo/Samsung-esys.jpg"/>
#                </a>
#               </div>
#               <div class="row banners banners-with-padding-45">
#                <a href="https://setec.mk/apple">
#                 <img alt="Banner" src="image/catalog/Promo/Bellow_slider_link-to-SIS.png"/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="row">
#              <div class="col-sm-12">
#               <div class="text-center">
#                © 2022 Сетек Сè од Техника.
#                <ul class="social-icons-default" style="padding-top: 7px">
#                 <li>
#                  <a href="https://www.facebook.com/setec.com.mk">
#                   <i class="fa fa-facebook">
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://www.youtube.com/user/SetecSeodTehnika/videos">
#                   <i class="fa fa-youtube-play">
#                   </i>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script src="catalog/view/theme/fastor/js/megamenu.js" type="text/javascript">
#     </script>
#    </div>
#   </div>
#   <!-- Facebook widget -->
#   <!-- /Facebook widget -->
#   <!-- Return to Top -->
#   <a href="javascript:" id="return-to-top">
#    <i class="icon-chevron-up">
#    </i>
#   </a>
#   <script>
#    // ===== Scroll to Top ====
# $(window).scroll(function() {
#     if ($(this).scrollTop() >= 50) {        // If page is scrolled more than 50px
#         $('#return-to-top').fadeIn(200);    // Fade in the arrow
#     } else {
#         $('#return-to-top').fadeOut(200);   // Else fade out the arrow
#     }
# });
# $('#return-to-top').click(function() {      // When arrow is clicked
#     $('body,html').animate({
#         scrollTop : 0                       // Scroll to top of body
#     }, 800);
# });
#   </script>
#   <style>
#    .vaucer {
#     animation: shake 1.2s cubic-bezier(.36,.07,.19,.97) both;
#     animation-duration: 1.2s;
#     animation-timing-function: cubic-bezier(0.36, 0.07, 0.19, 0.97);
#     animation-delay: 0s;
#     animation-iteration-count: 1;
#     animation-direction: normal;
#     animation-fill-mode: both;
#     animation-play-state: running;
#     animation-name: shake;
#     transform: translate3d(0, 0, 0);
#     backface-visibility: hidden;
#     perspective: 10000px;
# }
#   </style>
#   <script type="text/javascript">
#    //<![CDATA[
# $(window).load(function(){
# var x = Math.floor((Math.random() * 7) + 1);
# //document.getElementById("demo").innerHTML = x;
# $(function () {
# 	var x = Math.floor((Math.random() * 7) + 1);
# 		$(".filter-product .filter-tabs ul li:nth-child(1)").removeClass('active');
#         $(".filter-product .filter-tabs ul li:nth-child("+x+")").addClass("active");
# 		$(".tab-content.clearfix .tab-pane:nth-child(1)").removeClass('active');
# 		$(".tab-content.clearfix .tab-pane:nth-child("+x+")").addClass("active");
#     })
#     });//]]>
#   </script>
#   <script type="text/javascript">
#    var nitro_xhr;
# if (window.XMLHttpRequest){nitro_xhr=new XMLHttpRequest();}
# else{nitro_xhr=new ActiveXObject("Microsoft.XMLHTTP");}
# nitro_xhr.onreadystatechange=function(){if (nitro_xhr.readyState==4 && nitro_xhr.status==200){var nitroBarWrapper = document.createElement('div'); nitroBarWrapper.innerHTML = nitro_xhr.responseText; document.body.appendChild(nitroBarWrapper);}}
# nitro_xhr.open("GET","index.php?route=extension/module/nitro/getwidget&cachefile=MS04NjBlODE3MWVkYjM1Y2RjODFiODAzZjg4YWU1MzdjNi5odG1s&render_time=3.8046770095825",true);
# nitro_xhr.setRequestHeader("X-Requested-With", "XMLHttpRequest");
# nitro_xhr.send();
#   </script>
#  </body>
# </html>

# %% [markdown]
# * class selector - starts with '.' and continues with the name of the class
# (example '.sale')
#
# * id selector - starts with '#' and continues with the name of the id (example '#id')
#
# * tag names - example 'p': paragraph, 'a': anchor (link), 'div' - division

# %%
regular_price = soup.select(".price-old-new")

# %%
len(regular_price)
# Out:
# 81

# %%
happy_price = soup.select(".price-new-new")

# %%
len(happy_price)
# Out:
# 81

# %%
discount = soup.select(".sale")

# %%
len(discount)
# Out:
# 69

# %% [markdown]
# Notice that not all products have a discount

# %% [markdown]
# Tag selector

# %%
soup.select('p')
# Out:
# [<p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank">
#  <img alt="Club_Card" src="image/catalog/market/Card.png">Клуб Картичка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://cc.st.mk/Account/SignIn.aspx" style="color:white;">
#  <img alt="Cashback" src="image/catalog/market/cashback.png">Cashback Проверка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank">
#  <img alt="outlet-stamp" src="image/catalog/market/outlet-stamp.png">Оутлет Производи</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=679" style="color:white;" target="_blank">
#  <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png">Испорака</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank">
#  <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png">Вредносен Ваучер</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="index.php?route=information/information&amp;information_id=651" style="color:white;">
#  <img alt="icon_eco" src="image/catalog/market/eko.png"/>ЕКО Акција</a>
#  </p>,
#  <p><strong id="total_price_ajax"><span id="total_price">0 Ден.</span></strong></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank">
#  <img alt="Club_Card" src="image/catalog/market/Card.png">Клуб Картичка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://cc.st.mk/Account/SignIn.aspx" style="color:white;">
#  <img alt="Cashback" src="image/catalog/market/cashback.png">Cashback Проверка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank">
#  <img alt="outlet-stamp" src="image/catalog/market/outlet-stamp.png">Оутлет Производи</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=679" style="color:white;" target="_blank">
#  <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png">Испорака</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank">
#  <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png">Вредносен Ваучер</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="index.php?route=information/information&amp;information_id=651" style="color:white;">
#  <img alt="icon_eco" src="image/catalog/market/eko.png">ЕКО Акција</img></a>
#  </p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p>Претплатете се на билтенот<br/>и добијте попуст</p>]

# %% [markdown]
# Id selector

# %%
soup.select_one("#mora_da_ima_prazno_mesto")
# Out:
# <div class="name" id="mora_da_ima_prazno_mesto"><a href="https://setec.mk/tcl-65c74577352">
# 				TCL 65C745</a>
# </div>

# %% [markdown]
# The find and find_all functions

# %%
soup.find("p")
# Out:
# <p class="close-menu"></p>

# %%
soup.find_all("p")
# Out:
# [<p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank">
#  <img alt="Club_Card" src="image/catalog/market/Card.png">Клуб Картичка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://cc.st.mk/Account/SignIn.aspx" style="color:white;">
#  <img alt="Cashback" src="image/catalog/market/cashback.png">Cashback Проверка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank">
#  <img alt="outlet-stamp" src="image/catalog/market/outlet-stamp.png">Оутлет Производи</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=679" style="color:white;" target="_blank">
#  <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png">Испорака</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank">
#  <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png">Вредносен Ваучер</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="index.php?route=information/information&amp;information_id=651" style="color:white;">
#  <img alt="icon_eco" src="image/catalog/market/eko.png"/>ЕКО Акција</a>
#  </p>,
#  <p><strong id="total_price_ajax"><span id="total_price">0 Ден.</span></strong></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank">
#  <img alt="Club_Card" src="image/catalog/market/Card.png">Клуб Картичка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://cc.st.mk/Account/SignIn.aspx" style="color:white;">
#  <img alt="Cashback" src="image/catalog/market/cashback.png">Cashback Проверка</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank">
#  <img alt="outlet-stamp" src="image/catalog/market/outlet-stamp.png">Оутлет Производи</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=679" style="color:white;" target="_blank">
#  <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png">Испорака</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank">
#  <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png">Вредносен Ваучер</img></a>
#  </p>,
#  <p>
#  <a class="stat2" href="index.php?route=information/information&amp;information_id=651" style="color:white;">
#  <img alt="icon_eco" src="image/catalog/market/eko.png">ЕКО Акција</img></a>
#  </p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p>Претплатете се на билтенот<br/>и добијте попуст</p>]

# %%
soup.find_all("span")
# Out:
# [<span><strong>Компјутери и IT Опрема</strong></span>,
#  <span><strong>Преносни Компјутери и Таблети</strong></span>,
#  <span><strong> Конзоли за играње</strong></span>,
#  <span><strong>ТВ / Аудио / Видео</strong></span>,
#  <span><strong>Мобилни Телефони</strong></span>,
#  <span><strong>Фото и Навигација</strong></span>,
#  <span><strong>Бела Техника</strong></span>,
#  <span><strong>Мали Апарати</strong></span>,
#  <span><strong>Професионална Климатизација</strong></span>,
#  <span><strong>Ладење и Греење</strong></span>,
#  <span><strong>Електричен и рачен алат</strong></span>,
#  <span><strong>Спорт и рекреација</strong></span>,
#  <span><strong>Оптички Уреди</strong></span>,
#  <span><strong>Осветлување и Батерии</strong></span>,
#  <span><strong>Фотоволтаици</strong></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span><strong>За нас</strong></span>,
#  <span><strong>Cashback проверка</strong></span>,
#  <span><strong>Продажни салони</strong></span>,
#  <span><strong>Кариера</strong></span>,
#  <span><strong>Контакт</strong></span>,
#  <span><strong><img alt="" src="https://setec.mk/image/catalog/stationery2/icon-phone.png"/>Онлајн нарачка 02 30 80 899</strong></span>,
#  <span id="total_count_ajax">0</span>,
#  <span id="total_price">0 Ден.</span>,
#  <span><strong>Компјутери и IT Опрема</strong></span>,
#  <span><strong>Преносни Компјутери и Таблети</strong></span>,
#  <span><strong> Конзоли за играње</strong></span>,
#  <span><strong>ТВ / Аудио / Видео</strong></span>,
#  <span><strong>Мобилни Телефони</strong></span>,
#  <span><strong>Фото и Навигација</strong></span>,
#  <span><strong>Бела Техника</strong></span>,
#  <span><strong>Мали Апарати</strong></span>,
#  <span><strong>Професионална Климатизација</strong></span>,
#  <span><strong>Ладење и Греење</strong></span>,
#  <span><strong>Електричен и рачен алат</strong></span>,
#  <span><strong>Спорт и рекреација</strong></span>,
#  <span><strong>Оптички Уреди</strong></span>,
#  <span><strong>Осветлување и Батерии</strong></span>,
#  <span><strong>Фотоволтаици</strong></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span><strong>За нас</strong></span>,
#  <span><strong>Cashback проверка</strong></span>,
#  <span><strong>Продажни салони</strong></span>,
#  <span><strong>Кариера</strong></span>,
#  <span><strong>Контакт</strong></span>,
#  <span><strong><img alt="" src="https://setec.mk/image/catalog/stationery2/icon-phone.png"/>Онлајн нарачка 02 30 80 899</strong></span>,
#  <span class="comopl_label comopl_mod-270 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 90px;width: 80px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/2+3TCL.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">74,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">44,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										3,900 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										2,007 Ден.</span>,
#  <span class="comopl_label comopl_mod-270 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 90px;width: 80px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/2+3TCL.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">45,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,427 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,249 Ден.</span>,
#  <span class="comopl_label comopl_mod-270 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 90px;width: 80px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/2+3TCL.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">37,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,994 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,026 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">15,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										910 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										469 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">53,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">36,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										3,207 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,650 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">36,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">24,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,124 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,093 Ден.</span>,
#  <span class="comopl_label comopl_mod-304 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 80px;width: 90px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/5y-warranty_hisense.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">39,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">30,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,687 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,382 Ден.</span>,
#  <span class="comopl_label comopl_mod-304 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 80px;width: 90px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/5y-warranty_hisense.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">19,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">15,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,387 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										714 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">59,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">39,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										3,467 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,784 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">36,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">28,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,514 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,293 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">47,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,427 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,249 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">19,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">12,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,127 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										580 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">25,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">14,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,257 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										647 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">9,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">4,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										434 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										223 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">4,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">4,299 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										373 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										192 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">3,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										347 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										179 Ден.</span>,
#  <span class="comopl_label comopl_mod-439 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 70px;width: 60px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/apple authorized reseller.jpg'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">69,990 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">54,990 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										4,766 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										2,452 Ден.</span>,
#  <span class="comopl_label comopl_mod-439 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 70px;width: 60px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/apple authorized reseller.jpg'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">45,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">32,990 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,859 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,471 Ден.</span>,
#  <span class="comopl_label comopl_mod-439 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 70px;width: 60px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/apple authorized reseller.jpg'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-381 comopl_page-other" style="right: 0%;bottom: 0%;opacity: 1;height: 120px;width: 90px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/eyecather_11.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">44,990 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">27,990 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,426 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,248 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">54,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">47,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										4,000 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,000 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">32,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">23,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,080 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,070 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">18,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,647 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										847 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">13,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										954 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										491 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">12,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">9,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										867 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										446 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">4,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										434 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										223 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">21,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">17,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,560 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										803 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">21,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">19,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,734 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										892 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">21,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,907 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										981 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">26,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,994 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,026 Ден.</span>,
#  <span class="comopl_label comopl_mod-352 comopl_page-other" style="right: 0%;bottom: 0%;opacity: 1;height: 80px;width: 80px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/i5.jpg'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">28,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">24,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,167 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,115 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">31,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,427 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,249 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">38,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,947 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,516 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">41,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">35,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										3,120 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,605 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">27,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">24,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,167 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,115 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">36,990 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,947 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,516 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">50,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">50,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										4,420 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										2,274 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">8,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										737 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										379 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">13,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										910 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										469 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">10,799 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">9,299 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										806 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										415 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">8,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										694 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										357 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">35,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,947 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,516 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">8,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										694 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										357 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">8,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										780 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										402 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">11,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										910 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										469 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">8,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										694 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										357 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,994 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,026 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">23,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">19,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,734 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										892 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">13,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										954 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										491 Ден.</span>,
# ...
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">5,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">5,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										477 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										246 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">2,399 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">2,399 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										208 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										107 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">8,799 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										763 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										393 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">2,299 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">1,799 Ден.</span>,
#  <span class="klub-rata">РАТИ: </span>,
#  <span class="tooltiptext_nov">Производи со цена помала од 2000 ден. немаат можност да се купат на рати.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">2,699 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">2,699 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										234 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										121 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">2,099 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">2,099 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										182 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										94 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">2,799 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">2,799 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										243 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										125 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">4,299 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">3,199 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										278 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										143 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">3,859 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">3,859 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										335 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										173 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">4,399 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">4,399 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										382 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										197 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">6,139 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">6,139 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										532 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										274 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">1,099 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">1,099 Ден.</span>,
#  <span class="klub-rata">РАТИ: </span>,
#  <span class="tooltiptext_nov">Производи со цена помала од 2000 ден. немаат можност да се купат на рати.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">1,899 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">1,499 Ден.</span>,
#  <span class="klub-rata">РАТИ: </span>,
#  <span class="tooltiptext_nov">Производи со цена помала од 2000 ден. немаат можност да се купат на рати.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">4,399 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">3,599 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										312 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										161 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">19,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">12,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										1,127 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										580 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">3,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">3,499 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										304 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										156 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">52,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">32,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,860 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,472 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">28,999 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">25,999 Ден.</span>,
#  <span class="klub-rata">12 РАТИ: </span>,
#  <span class="klub-rata-suma">										2,254 Ден.</span>,
#  <span class="klub-rata">24 РАТИ: </span>,
#  <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										1,160 Ден.</span>,
#  <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
#  </span>,
#  <span class="redovna-cena">Редовна цена: </span>,
#  <span class="price-old-new">1,499 Ден.</span>,
#  <span class="akciska-cena">КЛУБ ЦЕНА: </span>,
#  <span class="price-new-new">899 Ден.</span>,
#  <span class="klub-rata">РАТИ: </span>,
#  <span class="tooltiptext_nov">Производи со цена помала од 2000 ден. немаат можност да се купат на рати.</span>]

# %% [markdown]
# More specific selectors

# %%
soup.select("div.category-price-akciska span.price-new-new")
# Out:
# [<span class="price-new-new">44,999 Ден.</span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="price-new-new">36,999 Ден.</span>,
#  <span class="price-new-new">24,499 Ден.</span>,
#  <span class="price-new-new">30,999 Ден.</span>,
#  <span class="price-new-new">15,999 Ден.</span>,
#  <span class="price-new-new">39,999 Ден.</span>,
#  <span class="price-new-new">28,999 Ден.</span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="price-new-new">12,999 Ден.</span>,
#  <span class="price-new-new">14,499 Ден.</span>,
#  <span class="price-new-new">4,999 Ден.</span>,
#  <span class="price-new-new">4,299 Ден.</span>,
#  <span class="price-new-new">3,999 Ден.</span>,
#  <span class="price-new-new">54,990 Ден.</span>,
#  <span class="price-new-new">32,990 Ден.</span>,
#  <span class="price-new-new">27,990 Ден.</span>,
#  <span class="price-new-new">47,999 Ден.</span>,
#  <span class="price-new-new">23,999 Ден.</span>,
#  <span class="price-new-new">18,999 Ден.</span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="price-new-new">9,999 Ден.</span>,
#  <span class="price-new-new">4,999 Ден.</span>,
#  <span class="price-new-new">17,999 Ден.</span>,
#  <span class="price-new-new">19,999 Ден.</span>,
#  <span class="price-new-new">21,999 Ден.</span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="price-new-new">24,999 Ден.</span>,
#  <span class="price-new-new">27,999 Ден.</span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="price-new-new">35,999 Ден.</span>,
#  <span class="price-new-new">24,999 Ден.</span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="price-new-new">50,999 Ден.</span>,
#  <span class="price-new-new">8,499 Ден.</span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="price-new-new">9,299 Ден.</span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="price-new-new">33,999 Ден.</span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="price-new-new">8,999 Ден.</span>,
#  <span class="price-new-new">10,499 Ден.</span>,
#  <span class="price-new-new">7,999 Ден.</span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="price-new-new">19,999 Ден.</span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="price-new-new">9,999 Ден.</span>,
#  <span class="price-new-new">3,499 Ден.</span>,
#  <span class="price-new-new">13,999 Ден.</span>,
#  <span class="price-new-new">15,999 Ден.</span>,
#  <span class="price-new-new">16,999 Ден.</span>,
#  <span class="price-new-new">22,999 Ден.</span>,
#  <span class="price-new-new">17,999 Ден.</span>,
#  <span class="price-new-new">14,999 Ден.</span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="price-new-new">31,999 Ден.</span>,
#  <span class="price-new-new">14,999 Ден.</span>,
#  <span class="price-new-new">7,499 Ден.</span>,
#  <span class="price-new-new">18,999 Ден.</span>,
#  <span class="price-new-new">10,999 Ден.</span>,
#  <span class="price-new-new">5,499 Ден.</span>,
#  <span class="price-new-new">2,399 Ден.</span>,
#  <span class="price-new-new">8,799 Ден.</span>,
#  <span class="price-new-new">1,799 Ден.</span>,
#  <span class="price-new-new">2,699 Ден.</span>,
#  <span class="price-new-new">2,099 Ден.</span>,
#  <span class="price-new-new">2,799 Ден.</span>,
#  <span class="price-new-new">3,199 Ден.</span>,
#  <span class="price-new-new">3,859 Ден.</span>,
#  <span class="price-new-new">4,399 Ден.</span>,
#  <span class="price-new-new">6,139 Ден.</span>,
#  <span class="price-new-new">1,099 Ден.</span>,
#  <span class="price-new-new">1,499 Ден.</span>,
#  <span class="price-new-new">3,599 Ден.</span>,
#  <span class="price-new-new">12,999 Ден.</span>,
#  <span class="price-new-new">3,499 Ден.</span>,
#  <span class="price-new-new">32,999 Ден.</span>,
#  <span class="price-new-new">25,999 Ден.</span>,
#  <span class="price-new-new">899 Ден.</span>]

# %% [markdown]
# Find tags with attributes, you can add multiple key-value pairs for the attrubte names and values.

# %%
soup.find_all('a', attrs={"data-original-title": "Додади во кошничка"})
# Out:
# [<a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77352');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76638');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76123');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77207');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57453');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57487');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77276');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77069');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56576');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('58712');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77924');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78226');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56484');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56481');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('33737');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('33993');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56769');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('50685');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('49406');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77654');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57685');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57680');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77697');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78171');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77869');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('55012');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57030');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56123');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('58255');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56657');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56565');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56273');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57784');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('58235');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('57003');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('58236');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('33855');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('32927');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('56221');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('33732');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('20679');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('20307');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76643');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77748');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('69900');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76297');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77814');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76705');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('70936');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77570');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('60906');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('68734');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76704');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76427');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('73799');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78260');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78257');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77638');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77737');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78296');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77623');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('73893');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('70669');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77065');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('72219');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('75262');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('33457');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('72430');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('74648');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('72605');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77155');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('74129');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('71179');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('73466');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('73403');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('34938');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('31976');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('12491');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('73958');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('76582');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('78028');"><i class="fa fa-shopping-cart"></i></a>,
#  <a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('75437');"><i class="fa fa-shopping-cart"></i></a>]

# %% [markdown]
# Scrape all products from the home page

# %%
products = soup.select('.product')

# %%
print(products[0])
# Out:
# <div class="product clearfix product-hover">
# <div class="left">
# <div class="sale">-40%</div>
# <div class="image">
# <a href="https://setec.mk/tcl-65c74577352">
# <!-- Como LABELS -->
# <!--&& $manufacturer!=15 -->
# <div class="comopl" id="comopl1"><div class="comopl_box">
# <span class="comopl_label comopl_mod-270 comopl_page-other" style="left: 0%;bottom: 0%;opacity: 1;height: 90px;width: 80px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/2+3TCL.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
# </span>
# </div>
# <div class="comopl_box">
# <span class="comopl_label comopl_mod-450 comopl_page-other" style="right: 0%;top: 0%;opacity: 1;height: 100px;width: 100px;font-size: 1em;font-weight: 700;text-align: center;border-style: none;border: none;box-shadow: none;background-image: url('https://setec.mk/image/catalog/Promo/iute_eye.png'); background-position: center; background-repeat: no-repeat;z-index: 1;">
# </span>
# </div>
# </div> <!-- Como LABELS end -->
# <!--	<div class="ClubCardPoints" style="position: absolute;top: 0pt;right: 5pt;z-index: 1;text-align: center;background: -webkit-linear-gradient(left,#3e5fa9 0,#3e5fa9 100%); border-radius: 50%; width: 100px; height: 100px;">
# 												<p class="keshback" style="font-size: 21pt;font-weight: 900;color: white;height: 24px;letter-spacing: -1pt;margin-top: 5px;">
# 																								</p>
# 						<p class="denaros" style="color:#f3812d;font-size: 14pt;font-weight: bold;letter-spacing: -1.5px;height: 13px;">CASH BACK</p>
# 						<p class="denaros" style="color:white;font-size: 12pt;">ПОЕНИ</p>
# 												<p class="keshback" style="font-size: 21pt;font-weight: 900;color: white;height: 24px;letter-spacing: -1pt;margin-top: 5px;">
# 																								</p>
# 						<p class="denaros" style="color:#f3812d;font-size: 14pt;font-weight: bold;letter-spacing: -1.5px;height: 13px;">CASH BACK</p>
# 						<p class="denaros" style="color:white;font-size: 12pt;">ПОЕНИ</p>
# 												</div> -->
# <img alt="TCL 65C745" class="zoom-image-effect" data-echo="https://setec.mk/image/cache/catalog/Product/77352_0-220x220.jpg" src="image/catalog/blank.gif"/>
# </a>
# </div>
# <!--<div class="24dostava" style="opacity: 1; height: 80px; width: 80px; background-image:url(https://setec.mk/image/catalog/Promo/24-48-dostava.png);
#     background-size: 80px !important; background-repeat: no-repeat; z-index: 1;"></div>-->
# </div>
# <div class="right">
# <div class="name" id="mora_da_ima_prazno_mesto"><a href="https://setec.mk/tcl-65c74577352">
# 				TCL 65C745</a>
# </div>
# <div class="shifra">
# 				Шифра: 77352			</div>
# <div class="lager">
# <div class="ima_zaliha" style="color:#47c353;">Производот е достапен</div>
# </div>
# <div class="price">
# <!-- Modul za vauceri -->
# <div class="cena-bace-cena-druze">
# <div class="category-price-redovna">
# <span class="redovna-cena">Редовна цена: </span>
# <span class="price-old-new">74,999 Ден.</span>
# </div>
# <div class="category-price-akciska">
# <span class="akciska-cena">КЛУБ ЦЕНА: </span>
# <p style="clear: both; text-align: center; margin: 2px !important;"></p>
# <span class="price-new-new">44,999 Ден.</span>
# </div>
# <!-- RATI -->
# <div id="category-rata">
# <span class="klub-rata">12 РАТИ: </span>
# <span class="klub-rata-suma">										3,900 Ден.</span><br/>
# <span class="klub-rata">24 РАТИ: </span>
# <!--style="border-radius: 1300em 0em 6em 1300em;
# 					background-color: #3c9555;
# 					padding: 8px 62px;
# 					color: #fff;"-->
# <span class="klub-rata-suma"> <!--style="background-color: #3c9555;  margin: 60px;  padding: 8px;  color: #fff;"-->										2,007 Ден.</span><br/>
# </div>
# <!-- RATI -->
# </div>
# </div>
# <div class="only-hover">
# <ul>
# <li><a data-original-title="Додади во кошничка" data-toggle="tooltip" onclick="cart.add('77352');"><i class="fa fa-shopping-cart"></i></a></li>
# <li><a data-original-title="Додади за споредба" data-toggle="tooltip" onclick="compare.add('77352');"><i class="fa fa-exchange"></i></a></li>
# <li><a data-original-title="Додади во омилени" data-toggle="tooltip" onclick="wishlist.add('77352');"><i class="fa fa-heart"></i></a></li>
# </ul>
# </div>
# </div>
# </div>

# %% [markdown]
# Let's test out the selectors for a single product. Then we will use them for all products on the home page.

# %%
product = products[0]

# %%
name = product.select_one('.name').text
code = product.select_one('.shifra').text
regular_price = product.select_one('.price-old-new').text
happy_price = product.select_one('.price-new-new').text
discount = product.select_one('.sale').text
link = product.select_one('.image a').get("href")
image_link = product.select_one('.image img').get("data-echo")

# %%
product.select_one('.image img').get("data-echo")
# Out:
# 'https://setec.mk/image/cache/catalog/Product/56939_0-228x228.jpg'

# %%
name, code, regular_price, happy_price, discount, link, image_link
# Out:
# ('\n\t\t\t\tLenovo DT Legion T7 34IRZ8 (Storm Grey)\n',
#  '\n\t\t\t\tШифра: 56939\t\t\t',
#  '199,999 Ден.',
#  '179,999 Ден.',
#  '-10%',
#  'https://setec.mk/компјутери-и-it-опрема/конфигурации/lenovo-dt-legion-t7-34irz8-storm-grey56939',
#  'https://setec.mk/image/cache/catalog/Product/56939_0-228x228.jpg')

# %%
name.strip()
# Out:
# 'TCL 65C745'

# %%
len(products)
# Out:
# 82

# %%
parsed_products = []
for product in products:
  name = product.select_one('.name').text.strip()
  code = product.select_one('.shifra').text.strip()
  regular_price = product.select_one('.price-old-new')
  if regular_price is not None:  # check to see if the element exists, if it's None it will throw an error
    regular_price = regular_price.text.strip()

  happy_price = product.select_one('.price-new-new')
  if happy_price is not None:
    happy_price = happy_price.text.strip()
  discount = product.select_one('.sale')
  if discount is not None:
    discount = discount.text.strip()
  link = product.select_one('.image a').get("href")
  image_link = product.select_one('.image img').get("data-echo")

  product_dict = {
      "ProductName": name,
      "ProductCode": code,
      "RegularPrice": regular_price,
      "HappyPrice": happy_price,
      "DiscountPercent": discount,
      "PageLink": link,
      "ImageLink": image_link
  }

  parsed_products.append(product_dict)

# %%
parsed_products
# Out:
# [{'ProductName': 'Apple Mac mini M2 PRO -',
#   'ProductCode': 'Шифра: 55218',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '89,999 Ден.',
#   'DiscountPercent': '-10%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/apple-mac-mini-m2-pro-55218',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/55218_0-228x228.jpg'},
#  {'ProductName': 'ASUS GAMING PC G35DX-WB7730W  /  Win 11',
#   'ProductCode': 'Шифра: 52738',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '89,999 Ден.',
#   'DiscountPercent': '-10%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/asus-gaming-pc-g35dx-wb7730w-win-1152738',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/52738_0-228x228.jpg'},
#  {'ProductName': 'Lenovo Legion T5 26ARA8',
#   'ProductCode': 'Шифра: 56987',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '92,999 Ден.',
#   'DiscountPercent': '-7%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=56987',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/56987_0-228x228.jpg'},
#  {'ProductName': 'Apple iMac 24" ( Blue ) - Процесор:Apple M3 chip with 8-core CPU  /   GPU  8-core',
#   'ProductCode': 'Шифра: 59281',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '94,999 Ден.',
#   'DiscountPercent': '-5%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59281',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59281_0-228x228.jpg'},
#  {'ProductName': 'Apple iMac 24" ( Green ) - Процесор:Apple M3 chip with 8-core CPU  /   GPU  8-core',
#   'ProductCode': 'Шифра: 59100',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '94,999 Ден.',
#   'DiscountPercent': '-5%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59100',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59100_0-228x228.jpg'},
#  {'ProductName': 'Конфигурација INTEL GAMER WARRIOR',
#   'ProductCode': 'Шифра: 57467',
#   'RegularPrice': '97,999 Ден.',
#   'HappyPrice': '94,999 Ден.',
#   'DiscountPercent': '-3%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/конфигурација-intel-gamer-warrior-57467',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/57467_0-228x228.jpg'},
#  {'ProductName': 'ASUS ROG STRIX GAMING PC G13CHR-M71470F16465',
#   'ProductCode': 'Шифра: 59715',
#   'RegularPrice': '99,999 Ден.',
#   'HappyPrice': '97,999 Ден.',
#   'DiscountPercent': '-2%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59715',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59715_0-228x228.jpg'},
#  {'ProductName': 'ASUS GAMING PC G15DS-WB7722W  /  Win 11',
#   'ProductCode': 'Шифра: 55819',
#   'RegularPrice': '109,999 Ден.',
#   'HappyPrice': '99,999 Ден.',
#   'DiscountPercent': '-9%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/asus-gaming-pc-g15ds-wb7722w-win-1155819',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/55819_0-228x228.jpg'},
#  {'ProductName': 'Конфигурација INTEL GAMER EXTREME',
#   'ProductCode': 'Шифра: 54337',
#   'RegularPrice': '119,999 Ден.',
#   'HappyPrice': '99,999 Ден.',
#   'DiscountPercent': '-17%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/конфигурација-intel-gamer-extreme-54337',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/54337_0-228x228.jpg'},
#  {'ProductName': 'Apple iMac 24" ( Blue ) - Процесор:Apple M3 chip with 8-core CPU  /   GPU  10-core',
#   'ProductCode': 'Шифра: 59099',
#   'RegularPrice': '115,999 Ден.',
#   'HappyPrice': '104,999 Ден.',
#   'DiscountPercent': '-9%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59099',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59099_0-228x228.jpg'},
#  {'ProductName': 'Apple iMac 24" ( Silver ) - Процесор:Apple M3 chip with 8-core CPU  /   GPU  10-core',
#   'ProductCode': 'Шифра: 57125',
#   'RegularPrice': '115,999 Ден.',
#   'HappyPrice': '104,999 Ден.',
#   'DiscountPercent': '-9%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/apple-imac-24-silver-процесор:apple-m3-chip-with-8-core-cpu-gpu-10-core57125',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/57125_0-228x228.jpg'},
#  {'ProductName': 'Lenovo Legion T5 26IRB8',
#   'ProductCode': 'Шифра: 58910',
#   'RegularPrice': '109,999 Ден.',
#   'HappyPrice': '104,999 Ден.',
#   'DiscountPercent': '-5%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=58910',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/58910_0-228x228.jpg'},
#  {'ProductName': 'Lenovo Legion T5 26ARA8',
#   'ProductCode': 'Шифра: 56986',
#   'RegularPrice': '124,999 Ден.',
#   'HappyPrice': '114,999 Ден.',
#   'DiscountPercent': '-8%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=56986',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/56986_0-228x228.jpg'},
#  {'ProductName': 'Lenovo Legion T5 26IRB8',
#   'ProductCode': 'Шифра: 59067',
#   'RegularPrice': '129,999 Ден.',
#   'HappyPrice': '124,999 Ден.',
#   'DiscountPercent': '-4%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59067',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59067_0-228x228.jpg'},
#  {'ProductName': 'Конфигурација INTEL GAMER BEAST',
#   'ProductCode': 'Шифра: 54338',
#   'RegularPrice': '149,999 Ден.',
#   'HappyPrice': '124,999 Ден.',
#   'DiscountPercent': '-17%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/конфигурација-intel-gamer-beast-54338',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/54338_0-228x228.jpg'},
#  {'ProductName': 'ASUS ROG STRIX GAMING PC G16CHR-S71470F3247S',
#   'ProductCode': 'Шифра: 59716',
#   'RegularPrice': '131,999 Ден.',
#   'HappyPrice': '127,999 Ден.',
#   'DiscountPercent': '-3%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59716',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59716_0-228x228.jpg'},
#  {'ProductName': 'Lenovo Legion T5 26IRB8',
#   'ProductCode': 'Шифра: 59068',
#   'RegularPrice': '159,999 Ден.',
#   'HappyPrice': '149,999 Ден.',
#   'DiscountPercent': '-6%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59068',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59068_0-228x228.jpg'},
#  {'ProductName': 'ASUS ROG STRIX GAMING PC G16CHR-SL91490KF6447S',
#   'ProductCode': 'Шифра: 59717',
#   'RegularPrice': '176,999 Ден.',
#   'HappyPrice': '169,999 Ден.',
#   'DiscountPercent': '-4%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации?product_id=59717',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/59717_0-228x228.jpg'},
#  {'ProductName': 'Lenovo DT Legion T7 34IRZ8 (Storm Grey)',
#   'ProductCode': 'Шифра: 56939',
#   'RegularPrice': '199,999 Ден.',
#   'HappyPrice': '179,999 Ден.',
#   'DiscountPercent': '-10%',
#   'PageLink': 'https://setec.mk/компјутери-и-it-опрема/конфигурации/lenovo-dt-legion-t7-34irz8-storm-grey56939',
#   'ImageLink': 'https://setec.mk/image/cache/catalog/Product/56939_0-228x228.jpg'}]

# %%
df = pd.DataFrame(parsed_products)

# %%
df
# Out:
#                                           ProductName   ProductCode  \
# 0                             Apple Mac mini M2 PRO -  Шифра: 55218
# 1             ASUS GAMING PC G35DX-WB7730W  /  Win 11  Шифра: 52738
# 2                             Lenovo Legion T5 26ARA8  Шифра: 56987
# 3   Apple iMac 24" ( Blue ) - Процесор:Apple M3 ch...  Шифра: 59281
# 4   Apple iMac 24" ( Green ) - Процесор:Apple M3 c...  Шифра: 59100
# 5                   Конфигурација INTEL GAMER WARRIOR  Шифра: 57467
# 6        ASUS ROG STRIX GAMING PC G13CHR-M71470F16465  Шифра: 59715
# 7             ASUS GAMING PC G15DS-WB7722W  /  Win 11  Шифра: 55819
# 8                   Конфигурација INTEL GAMER EXTREME  Шифра: 54337
# 9   Apple iMac 24" ( Blue ) - Процесор:Apple M3 ch...  Шифра: 59099
# 10  Apple iMac 24" ( Silver ) - Процесор:Apple M3 ...  Шифра: 57125
# 11                            Lenovo Legion T5 26IRB8  Шифра: 58910
# 12                            Lenovo Legion T5 26ARA8  Шифра: 56986
# 13                            Lenovo Legion T5 26IRB8  Шифра: 59067
# 14                    Конфигурација INTEL GAMER BEAST  Шифра: 54338
# 15       ASUS ROG STRIX GAMING PC G16CHR-S71470F3247S  Шифра: 59716
# 16                            Lenovo Legion T5 26IRB8  Шифра: 59068
# 17     ASUS ROG STRIX GAMING PC G16CHR-SL91490KF6447S  Шифра: 59717
# 18            Lenovo DT Legion T7 34IRZ8 (Storm Grey)  Шифра: 56939
#
#     RegularPrice    HappyPrice DiscountPercent  \
# 0    99,999 Ден.   89,999 Ден.            -10%
# 1    99,999 Ден.   89,999 Ден.            -10%
# 2    99,999 Ден.   92,999 Ден.             -7%
# 3    99,999 Ден.   94,999 Ден.             -5%
# 4    99,999 Ден.   94,999 Ден.             -5%
# 5    97,999 Ден.   94,999 Ден.             -3%
# 6    99,999 Ден.   97,999 Ден.             -2%
# 7   109,999 Ден.   99,999 Ден.             -9%
# 8   119,999 Ден.   99,999 Ден.            -17%
# 9   115,999 Ден.  104,999 Ден.             -9%
# 10  115,999 Ден.  104,999 Ден.             -9%
# 11  109,999 Ден.  104,999 Ден.             -5%
# 12  124,999 Ден.  114,999 Ден.             -8%
# 13  129,999 Ден.  124,999 Ден.             -4%
# 14  149,999 Ден.  124,999 Ден.            -17%
# 15  131,999 Ден.  127,999 Ден.             -3%
# 16  159,999 Ден.  149,999 Ден.             -6%
# 17  176,999 Ден.  169,999 Ден.             -4%
# 18  199,999 Ден.  179,999 Ден.            -10%
#
#                                              PageLink  \
# 0   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 1   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 2   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 3   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 4   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 5   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 6   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 7   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 8   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 9   https://setec.mk/компјутери-и-it-опрема/конфиг...
# 10  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 11  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 12  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 13  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 14  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 15  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 16  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 17  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 18  https://setec.mk/компјутери-и-it-опрема/конфиг...
#
#                                             ImageLink
# 0   https://setec.mk/image/cache/catalog/Product/5...
# 1   https://setec.mk/image/cache/catalog/Product/5...
# 2   https://setec.mk/image/cache/catalog/Product/5...
# 3   https://setec.mk/image/cache/catalog/Product/5...
# 4   https://setec.mk/image/cache/catalog/Product/5...
# 5   https://setec.mk/image/cache/catalog/Product/5...
# 6   https://setec.mk/image/cache/catalog/Product/5...
# 7   https://setec.mk/image/cache/catalog/Product/5...
# 8   https://setec.mk/image/cache/catalog/Product/5...
# 9   https://setec.mk/image/cache/catalog/Product/5...
# 10  https://setec.mk/image/cache/catalog/Product/5...
# 11  https://setec.mk/image/cache/catalog/Product/5...
# 12  https://setec.mk/image/cache/catalog/Product/5...
# 13  https://setec.mk/image/cache/catalog/Product/5...
# 14  https://setec.mk/image/cache/catalog/Product/5...
# 15  https://setec.mk/image/cache/catalog/Product/5...
# 16  https://setec.mk/image/cache/catalog/Product/5...
# 17  https://setec.mk/image/cache/catalog/Product/5...
# 18  https://setec.mk/image/cache/catalog/Product/5...

# %%
df.head(10)
# Out:
#                                          ProductName   ProductCode  \
# 0                            Apple Mac mini M2 PRO -  Шифра: 55218
# 1            ASUS GAMING PC G35DX-WB7730W  /  Win 11  Шифра: 52738
# 2                            Lenovo Legion T5 26ARA8  Шифра: 56987
# 3  Apple iMac 24" ( Blue ) - Процесор:Apple M3 ch...  Шифра: 59281
# 4  Apple iMac 24" ( Green ) - Процесор:Apple M3 c...  Шифра: 59100
# 5                  Конфигурација INTEL GAMER WARRIOR  Шифра: 57467
# 6       ASUS ROG STRIX GAMING PC G13CHR-M71470F16465  Шифра: 59715
# 7            ASUS GAMING PC G15DS-WB7722W  /  Win 11  Шифра: 55819
# 8                  Конфигурација INTEL GAMER EXTREME  Шифра: 54337
# 9  Apple iMac 24" ( Blue ) - Процесор:Apple M3 ch...  Шифра: 59099
#
#    RegularPrice    HappyPrice DiscountPercent  \
# 0   99,999 Ден.   89,999 Ден.            -10%
# 1   99,999 Ден.   89,999 Ден.            -10%
# 2   99,999 Ден.   92,999 Ден.             -7%
# 3   99,999 Ден.   94,999 Ден.             -5%
# 4   99,999 Ден.   94,999 Ден.             -5%
# 5   97,999 Ден.   94,999 Ден.             -3%
# 6   99,999 Ден.   97,999 Ден.             -2%
# 7  109,999 Ден.   99,999 Ден.             -9%
# 8  119,999 Ден.   99,999 Ден.            -17%
# 9  115,999 Ден.  104,999 Ден.             -9%
#
#                                             PageLink  \
# 0  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 1  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 2  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 3  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 4  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 5  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 6  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 7  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 8  https://setec.mk/компјутери-и-it-опрема/конфиг...
# 9  https://setec.mk/компјутери-и-it-опрема/конфиг...
#
#                                            ImageLink
# 0  https://setec.mk/image/cache/catalog/Product/5...
# 1  https://setec.mk/image/cache/catalog/Product/5...
# 2  https://setec.mk/image/cache/catalog/Product/5...
# 3  https://setec.mk/image/cache/catalog/Product/5...
# 4  https://setec.mk/image/cache/catalog/Product/5...
# 5  https://setec.mk/image/cache/catalog/Product/5...
# 6  https://setec.mk/image/cache/catalog/Product/5...
# 7  https://setec.mk/image/cache/catalog/Product/5...
# 8  https://setec.mk/image/cache/catalog/Product/5...
# 9  https://setec.mk/image/cache/catalog/Product/5...

# %%
df.to_csv('products-setec.csv', index=False)

# %% [markdown]
# # Additional

# %% [markdown]
# ### How to scrape multiple pages?

# %% [markdown]
# Let's try to scrape all the keybords from their category page. The page implements paging so we can use the query parameter to move between pages.

# %%
base_url = "https://setec.mk/computers--it/pc-accessories/keybords?page="

# %% [markdown]
# The same code from above is copied in a function `extract_product_characteristics_as_dict` for easy access

# %%
def extract_product_characteristics_as_dict(product):
  name = product.select_one('.name').text.strip()
  code = product.select_one('.shifra').text.strip()
  regular_price = product.select_one('.price-old-new')
  if regular_price is not None:
    regular_price = regular_price.text.strip()

  happy_price = product.select_one('.price-new-new')
  if happy_price is not None:
    happy_price = happy_price.text.strip()
  discount = product.select_one('.sale')
  if discount is not None:
    discount = discount.text.strip()
  link = product.select_one('.image a').get("href")
  image_link = product.select_one('.image img').get("data-echo")

  product_dict = {
      "ProductName": name,
      "ProductCode": code,
      "RegularPrice": regular_price,
      "HappyPrice": happy_price,
      "DiscountPercent": discount,
      "PageLink": link,
      "ImageLink": image_link
  }

  return product_dict

# %%
all_products = []
for i in range(1, 6):  # there are 6 pages for keyboards
  url = base_url + str(i)
  response = requests.get(url)
  soup = BeautifulSoup(response.text, "html.parser")
  products = soup.select('.product')
  for product in products:
    result = extract_product_characteristics_as_dict(product)
    all_products.append(result)

# %%
all_pc_configs = pd.DataFrame(all_products)

# %%
all_pc_configs.to_csv('pc-configs-setec.csv', index=False)

# %% [markdown]
# # Homework: Find all links to categories and scrape the entire site
# Hint: Also find a way to automatically check the number of pages per category
